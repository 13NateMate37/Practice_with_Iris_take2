# %% [markdown]
# # **Semi-Guided Practice**

# %% [markdown]
# ## Objectives
#
# * This is an exercise for the sake of getting reps in whilst still trying to digest the on coming course material
#
# * Using AI to create practice scenarios, with the aim of whittling out the guidance as I progress
#
# * Based on the Iris dataset, handed out in virtual class for practice
#
# * Output
# This notebook will contain the ETL process and produce a worked dataset for visualisations and further statistical tests

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Practice_Projects\\pracIris\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Practice_Projects\\pracIris'

# %% [markdown]
# # Import block

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Section 1 - Extraction and initial inspection

# %%
# Open the csv as a pandas dataframe

df_raw = pd.read_csv("Dataset/Raw/Iris.csv")

df_raw.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
# Insepcting the initial construction of the data

print("Initial shape:", df_raw.shape)
print('=' * 50)
print("Data types:\n", df_raw.dtypes)
print('=' * 50)
print("missing value count:\n", df_raw.isnull().sum())
print('=' * 50)
print("Duplicates count:\n", df_raw.duplicated().sum())
df_raw.describe()
# Out:
# Initial shape: (150, 6)
# ...
# Data types:
#  Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object
# ...
# missing value count:
#  Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
# ...
# Duplicates count:
#  0
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# ...

# %% [markdown]
# The dataset is pretty clean with no missing values or duplicates.
#
# This should be really easy to work with.

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 - Transformation

# %% [markdown]
# We can move straight to some transformations and exploratory insights.

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In cases where you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create your folder here
  # os.makedirs(name='')
except Exception as e:
  print(e)
